# %%
# !nvidia-smi
# Out:
# Tue Feb 10 15:27:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 570.133.20             Driver Version: 570.133.20     CUDA Version: 12.8     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A40                     On  |   00000000:CA:00.0 Off |                    0 |
# |  0%   28C    P8             21W /  300W |       0MiB /  46068MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pwd
# Out:
# /home/s2410121/pytorch_tutorials/official_tutorials

# %%
# !cd ../

# %%
# !source pytorch_tutorials/bin/activate
# Out:
# /bin/bash: line 1: pytorch_tutorials/bin/activate: No such file or directory
